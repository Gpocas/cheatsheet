# %%
class ControleRemoto():
    
    def __init__(self, cor, altura, profundidade, largura):
        
        self.cor = cor
        self.altura = altura
        self.profundidade = profundidade
        self. largura = largura
        self.valor = input(''' Por favor escolha uma opção abaixo:
        (+) para aumentar o canal
        (-) para diminuir o canal
        ''')
        self.mudar_canal(self.valor)
        
               
    def mudar_canal(self, botao):
        if botao == '+':
            print('Aumentando canal')
        elif botao == '-':
            print(f'Diminuindo canal')
        else:
            raise ValueError('Opção invalida')

controle = ControleRemoto('preto', '10 cm', '2 cm', '12 cm')
# print(controle.cor)
# controle.mudar_canal(valor)
